# %%
import tensorflow as tf
hello = tf.constant("hello")
sess = tf.Session()
print(sess.run(hello))
# Out:
# C:\Users\young\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# b'hello'

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)
node3 = tf.add(node1, node2)

# %%
print("node1 = ", node1, "node2 = ", node2)
print("node3 = ", node3)
# Out:
# node1 =  Tensor("Const_3:0", shape=(), dtype=float32) node2 =  Tensor("Const_4:0", shape=(), dtype=float32)
# node3 =  Tensor("Add_1:0", shape=(), dtype=float32)

# %%
sess = tf.Session()
print("sess.run(node1, node2) = ", sess.run((node1, node2)))
print("sess.run(node3) = ", sess.run(node3))
# Out:
# sess.run(node1, node2) =  (3.0, 4.0)
# sess.run(node3) =  7.0

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b

print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict={a:[1,3], b:[2,4]}))

#scalar 0 
#vector 1
#metrix 2
# Out:
# 7.5
# [3. 7.]

# %%
########################################################

x = [1, 2, 3]
y = x.copy()
#y = [1, 2, 3]
#y = cp.copy(x)


w = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

"""
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print(sess.run(w))
"""

hypothesis = x * w + b
# Out:
# [-0.71107155]

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y))
#제곱이나 절대값?

# %%
#학습률
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(w), sess.run(b))
# Out:
# 0 0.032960948 [0.95450515] [0.2687004]
# 20 0.0078468295 [0.9043884] [0.23308542]
# 40 0.0069263536 [0.9039061] [0.21994245]
# 60 0.006288811 [0.90794843] [0.20939758]
# 80 0.005711579 [0.91222936] [0.19953683]
# 100 0.0051873466 [0.91635] [0.19015747]
# 120 0.004711235 [0.9202809] [0.18122053]
# 140 0.0042788214 [0.9240273] [0.1727038]
# 160 0.0038860897 [0.9275977] [0.16458736]
# 180 0.0035294064 [0.9310004] [0.1568524]
# 200 0.0032054714 [0.9342431] [0.14948092]
# 220 0.002911255 [0.9373334] [0.14245589]
# 240 0.0026440562 [0.9402785] [0.13576104]
# 260 0.0024013666 [0.9430852] [0.12938075]
# 280 0.0021809638 [0.9457599] [0.12330037]
# 300 0.0019807823 [0.948309] [0.11750574]
# 320 0.0017989866 [0.9507383] [0.11198339]
# 340 0.001633861 [0.9530535] [0.10672057]
# 360 0.0014838997 [0.9552598] [0.10170507]
# 380 0.0013477005 [0.9573624] [0.09692528]
# 400 0.0012240041 [0.9593663] [0.09237013]
# 420 0.0011116612 [0.96127594] [0.08802901]
# 440 0.0010096263 [0.96309584] [0.08389194]
# 460 0.0009169544 [0.96483016] [0.0799493]
# 480 0.0008327987 [0.966483] [0.07619199]
# 500 0.000756356 [0.96805817] [0.07261124]
# 520 0.00068693334 [0.96955943] [0.06919878]
# 540 0.0006238853 [0.97099] [0.06594662]
# 560 0.00056662393 [0.97235334] [0.06284735]
# 580 0.00051461393 [0.9736526] [0.05989376]
# 600 0.00046737932 [0.9748908] [0.05707899]
# 620 0.00042448504 [0.9760709] [0.05439649]
# 640 0.00038552468 [0.97719544] [0.05184007]
# 660 0.0003501377 [0.9782672] [0.0494038]
# 680 0.00031800466 [0.97928846] [0.04708203]
# 700 0.000288814 [0.980262] [0.04486936]
# 720 0.00026230613 [0.98118955] [0.04276063]
# 740 0.00023823015 [0.9820736] [0.04075099]
# 760 0.00021636488 [0.98291606] [0.03883584]
# 780 0.00019650561 [0.98371893] [0.0370107]
# 1920 8.1328704e-07 [0.99895257] [0.00238103]
# 1940 7.3863885e-07 [0.9990018] [0.00226914]
# 1960 6.708376e-07 [0.9990487] [0.00216251]
# 1980 6.0934894e-07 [0.9990934] [0.0020609]
# 2000 5.533845e-07 [0.9991359] [0.00196407]

# %%
########################################################

x = tf.placeholder(tf.float32, shape = [None])
y = tf.placeholder(tf.float32, shape = [None])

w = tf.Variable(tf.random_normal([1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias")

hypothesis = x * w + b

cost = tf.reduce_mean(tf.square(hypothesis - y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, w_val, b_val, __ = sess.run([cost, w, b, train],
                                         feed_dict = {x: [1,2,3,4,5],
                                                     y:[2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, w_val, b_val)

print('*'*30)

print(sess.run(hypothesis, feed_dict = {x:[5]}))
print(sess.run(hypothesis, feed_dict = {x:[2.5]}))
print(sess.run(hypothesis, feed_dict = {x:[1.5, 3.5]}))
# Out:
# 0 3.9435616 [1.6348995] [0.4353647]
# 20 0.0975959 [1.2039458] [0.37104198]
# 40 0.08516302 [1.1888306] [0.41829476]
# 60 0.07437348 [1.176456] [0.4629379]
# 80 0.06495089 [1.1648997] [0.5046596]
# 100 0.056722097 [1.1541004] [0.5436489]
# 120 0.04953588 [1.1440083] [0.58008474]
# 140 0.043260068 [1.1345769] [0.6141344]
# 160 0.03777934 [1.1257634] [0.6459541]
# 180 0.032992937 [1.117527] [0.67569005]
# 200 0.028812984 [1.10983] [0.7034786]
# 220 0.025162557 [1.102637] [0.7294471]
# 240 0.021974657 [1.0959153] [0.753715]
# 260 0.019190645 [1.0896338] [0.7763934]
# 280 0.016759317 [1.0837636] [0.7975867]
# 300 0.014636032 [1.0782778] [0.8173921]
# 320 0.012781751 [1.0731514] [0.8359002]
# 340 0.011162391 [1.0683606] [0.85319644]
# 360 0.009748194 [1.0638837] [0.86935985]
# 380 0.008513155 [1.0596998] [0.8844647]
# 400 0.007434604 [1.05579] [0.89858025]
# 420 0.0064926953 [1.0521362] [0.9117714]
# 440 0.005670104 [1.0487218] [0.9240989]
# 460 0.004951741 [1.0455309] [0.93561876]
# 480 0.004324409 [1.0425491] [0.9463842]
# 500 0.0037765373 [1.0397625] [0.95644456]
# 520 0.0032980728 [1.0371585] [0.965846]
# 540 0.0028802282 [1.034725] [0.97463185]
# 560 0.0025153374 [1.0324508] [0.9828422]
# 580 0.0021966647 [1.0303254] [0.99051505]
# 600 0.0019183571 [1.0283395] [0.9976853]
# 620 0.0016753199 [1.0264835] [1.004386]
# 640 0.0014630721 [1.0247492] [1.0106477]
# 660 0.0012777074 [1.0231283] [1.0164994]
# 680 0.0011158349 [1.0216137] [1.0219679]
# 700 0.00097446435 [1.020198] [1.0270783]
# 720 0.000851015 [1.0188754] [1.0318539]
# 740 0.000743201 [1.0176392] [1.0363168]
# 760 0.0006490376 [1.016484] [1.0404875]
# 780 0.0005668093 [1.0154045] [1.0443851]
# 800 0.00049499626 [1.0143955] [1.0480273]
# 820 0.00043228138 [1.0134529] [1.0514311]
# 840 0.0003775143 [1.0125718] [1.0546119]
# 860 0.00032968973 [1.0117484] [1.0575843]
# 880 0.0002879222 [1.010979] [1.0603622]
# 900 0.00025144417 [1.0102601] [1.062958]
# 920 0.00021959003 [1.009588] [1.0653838]
# 940 0.00019176681 [1.0089601] [1.0676509]
# 960 0.0001674762 [1.0083734] [1.0697693]
# 980 0.000146256 [1.007825] [1.0717492]
# 1000 0.00012772426 [1.0073124] [1.0735993]
# 1020 0.00011154504 [1.0068337] [1.0753284]
# 1040 9.7413125e-05 [1.006386] [1.0769441]
# 1060 8.507041e-05 [1.0059679] [1.078454]
# 1080 7.429249e-05 [1.005577] [1.0798655]
# 1100 6.4880274e-05 [1.0052118] [1.0811839]
# 1120 5.6658184e-05 [1.0048704] [1.0824162]
# 1140 4.9481827e-05 [1.0045514] [1.0835677]
# 1160 4.3212225e-05 [1.0042534] [1.0846437]
# 1180 3.7738122e-05 [1.0039748] [1.0856495]
# 1200 3.295603e-05 [1.0037144] [1.0865893]
# 1220 2.8782271e-05 [1.0034713] [1.0874676]
# 1240 2.5135407e-05 [1.0032439] [1.0882882]
# 1260 2.1950367e-05 [1.0030315] [1.0890553]
# 1280 1.9171115e-05 [1.002833] [1.0897717]
# 1300 1.6741997e-05 [1.0026475] [1.0904416]
# 1320 1.4621335e-05 [1.0024742] [1.0910676]
# 1340 1.276922e-05 [1.0023121] [1.0916525]
# 1360 1.1150526e-05 [1.0021607] [1.0921992]
# 1380 9.738338e-06 [1.0020192] [1.09271]
# 1400 8.505262e-06 [1.001887] [1.0931875]
# 1420 7.427147e-06 [1.0017633] [1.0936337]
# 1440 6.485928e-06 [1.0016478] [1.0940506]
# 1460 5.6640806e-06 [1.00154] [1.0944402]
# 1480 4.9474156e-06 [1.0014392] [1.094804]
# 1500 4.3205105e-06 [1.001345] [1.0951442]
# 1520 3.7735438e-06 [1.0012568] [1.0954622]
# 1540 3.295662e-06 [1.0011747] [1.0957593]
# 1560 2.8779777e-06 [1.0010978] [1.0960369]
# 1580 2.5134118e-06 [1.0010259] [1.0962964]
# 1600 2.194836e-06 [1.0009587] [1.0965389]
# 1620 1.9170443e-06 [1.0008959] [1.0967656]
# 1640 1.6742491e-06 [1.0008373] [1.0969772]
# 1660 1.4621692e-06 [1.0007825] [1.0971751]
# 1680 1.2770809e-06 [1.0007312] [1.09736]
# 1700 1.1152263e-06 [1.0006833] [1.0975329]
# 1720 9.741976e-07 [1.0006387] [1.0976944]
# 1740 8.507932e-07 [1.0005969] [1.0978452]
# 1760 7.432317e-07 [1.0005579] [1.0979861]
# 1780 6.4901064e-07 [1.0005213] [1.0981181]
# 1800 5.6690516e-07 [1.0004872] [1.0982411]
# 1820 4.950001e-07 [1.0004554] [1.0983564]
# 1840 4.3236258e-07 [1.0004256] [1.098464]
# 1860 3.7763272e-07 [1.0003977] [1.0985644]
# 1880 3.2982302e-07 [1.0003716] [1.0986583]
# 1900 2.8802492e-07 [1.0003474] [1.0987462]
# 1920 2.5156558e-07 [1.0003246] [1.0988282]
# 1940 2.1974071e-07 [1.0003033] [1.0989047]
# 1960 1.9197314e-07 [1.0002836] [1.0989764]
# 1980 1.6765367e-07 [1.0002649] [1.0990434]
# 2000 1.4644739e-07 [1.0002477] [1.099106]
# ******************************
# [6.1003447]
# [3.5997252]
# [2.5994775 4.5999727]
